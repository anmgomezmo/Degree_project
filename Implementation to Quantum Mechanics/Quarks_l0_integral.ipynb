# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
import time

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = "cpu"
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Neural Network Model

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.layers = nn.Sequential(
        nn.Linear(1,10),
        nn.Sigmoid(),
        nn.Linear(10,1, bias=False)
        )
        
    def forward(self, x):
        N = self.layers(x)
        return N

# %%
def training(x, loss_fn, optimizer):
    x = x.to(device)
    def closure():
        loss = loss_fn(x)
        optimizer.zero_grad()
        loss.backward()
        return loss
    torch.nn.utils.clip_grad_value_(model.parameters(), 2)
    optimizer.step(closure)

# %% [markdown]
# ### Differential equation
# $$\frac{d^2\phi(r)}{dr^2} + \frac{2m}{\hbar^2}\left(E-\frac{l(l+1)}{2mr^2}\hbar^2+V(r)\right)\phi(r) = 0$$
# Dataset are vectors of domain of differential equation, like the vectors are one-dimentional, the shape of dataset is one by m samples. Trial solution $\phi_t(r) = e^{-\beta r^2}N(r,\vec{p})$, with $\phi(r=0) = 0$ and $\phi(r\rightarrow\infty) = 0$ as boundary conditions.

# %%
beta = 2
global Z
Z = 1
global e
#e = -1.602e-19
e = -1
global hbar
#hbar = 1.054e-34
hbar = 1
global m
#m = 9.109e-31
m = 1
global l
l = 0

V = lambda r: -(Z*e**2)/r + r
Phi_t = lambda r: r*torch.exp(-beta*r**2) * model.forward(r)

# %%
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Linear)):
            nn.init.xavier_normal_(m.weight.data)

# %%
def loss_fn(r):
    r.requires_grad = True
    
    Phi = Phi_t(r)    
    Phi_t_r = torch.autograd.grad(Phi, r, grad_outputs=torch.ones_like(Phi), create_graph=True)[0]
    Phi_t_r_r = torch.autograd.grad(Phi_t_r, r, grad_outputs=torch.ones_like(Phi_t_r), create_graph=True)[0]
    H_Phi = -(hbar**2/(2*m))*Phi_t_r_r + (l*(l+1)*hbar**2/(2*m*r**2) + V(r))*Phi
    
    norm = torch.trapezoid(Phi[100:]**2,r[100:],dim=0) # integral over r=0 to 6

    prom = Phi.size()[0]
    
    global E
    E = torch.trapezoid(Phi[100:]*H_Phi[100:],r[100:],dim=0)/norm 
    
    
    return (torch.mean((H_Phi[100:] - E*Phi[100:])**2)*prom)/norm #multiply by m to avoit division by m in the mean function of torh

# %%
upper_r = 6
lower_r = -6
steps = 200
R_train = torch.Tensor(np.linspace(lower_r, upper_r, steps)[:,None])
epoch = 10000
lr = 8e-3
Phis_t = []
Es = []
lss = []
epochs = []



start = time.time()

model = NeuralNetwork().to(device)
initialize_weights(model)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
for t in range(epoch+1):
    loss = loss_fn(R_train.to(device))
    print(f"Epoch {t+1}\n ---------------------- loss: {loss}")
    training(R_train, loss_fn, optimizer)
    if t%1 == 0:
        Phis_t.append(Phi_t(R_train.to(device)).data.cpu().numpy())
        Es.append(E.cpu().detach().numpy())
        lss.append(loss.cpu().detach().numpy())
        epochs.append(t)
Es = np.squeeze(Es)
lss = np.squeeze(lss)
Phis_t = np.squeeze(Phis_t)
print("Done!")

end = time.time()
print(end - start)
# Out:
# Epoch 1
#  ---------------------- loss: tensor([177.4158], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 2
#  ---------------------- loss: tensor([136.4477], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 3
#  ---------------------- loss: tensor([134.2099], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 4
#  ---------------------- loss: tensor([133.2648], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 5
#  ---------------------- loss: tensor([132.6847], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 6
#  ---------------------- loss: tensor([132.2667], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 7
#  ---------------------- loss: tensor([131.9377], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 8
#  ---------------------- loss: tensor([131.6644], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9
#  ---------------------- loss: tensor([131.4290], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 10
#  ---------------------- loss: tensor([131.2210], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 11
#  ---------------------- loss: tensor([131.0337], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 12
#  ---------------------- loss: tensor([130.8626], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 13
#  ---------------------- loss: tensor([130.7045], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 14
#  ---------------------- loss: tensor([130.5572], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 15
#  ---------------------- loss: tensor([130.4189], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 16
#  ---------------------- loss: tensor([130.2884], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 17
#  ---------------------- loss: tensor([130.1646], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 18
#  ---------------------- loss: tensor([130.0467], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 19
#  ---------------------- loss: tensor([129.9341], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 20
#  ---------------------- loss: tensor([129.8262], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 21
#  ---------------------- loss: tensor([129.7226], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 22
#  ---------------------- loss: tensor([129.6229], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 23
#  ---------------------- loss: tensor([129.5267], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 24
#  ---------------------- loss: tensor([129.4339], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 25
#  ---------------------- loss: tensor([129.3442], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 26
#  ---------------------- loss: tensor([129.2574], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 27
#  ---------------------- loss: tensor([129.1734], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 28
#  ---------------------- loss: tensor([129.0920], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 29
#  ---------------------- loss: tensor([129.0129], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 30
#  ---------------------- loss: tensor([128.9363], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 31
#  ---------------------- loss: tensor([128.8618], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 32
#  ---------------------- loss: tensor([128.7895], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 33
#  ---------------------- loss: tensor([128.7192], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 34
#  ---------------------- loss: tensor([128.6509], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 35
#  ---------------------- loss: tensor([128.5845], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 36
#  ---------------------- loss: tensor([128.5199], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 37
#  ---------------------- loss: tensor([128.4571], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 38
#  ---------------------- loss: tensor([128.3959], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 39
#  ---------------------- loss: tensor([128.3365], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 40
#  ---------------------- loss: tensor([128.2786], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 41
#  ---------------------- loss: tensor([128.2222], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 42
#  ---------------------- loss: tensor([128.1674], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 43
#  ---------------------- loss: tensor([128.1140], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 44
#  ---------------------- loss: tensor([128.0620], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 45
#  ---------------------- loss: tensor([128.0114], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 46
#  ---------------------- loss: tensor([127.9620], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 47
#  ---------------------- loss: tensor([127.9139], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 48
#  ---------------------- loss: tensor([127.8671], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 49
#  ---------------------- loss: tensor([127.8214], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 50
#  ---------------------- loss: tensor([127.7770], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 51
#  ---------------------- loss: tensor([127.7336], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 52
#  ---------------------- loss: tensor([127.6913], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 53
#  ---------------------- loss: tensor([127.6500], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 54
#  ---------------------- loss: tensor([127.6098], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 55
#  ---------------------- loss: tensor([127.5705], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 56
#  ---------------------- loss: tensor([127.5321], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 57
#  ---------------------- loss: tensor([127.4947], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 58
#  ---------------------- loss: tensor([127.4581], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 59
#  ---------------------- loss: tensor([127.4223], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 60
#  ---------------------- loss: tensor([127.3873], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 61
#  ---------------------- loss: tensor([127.3530], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 62
#  ---------------------- loss: tensor([127.3195], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 63
#  ---------------------- loss: tensor([127.2867], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 64
#  ---------------------- loss: tensor([127.2545], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 65
#  ---------------------- loss: tensor([127.2230], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 66
#  ---------------------- loss: tensor([127.1920], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 67
#  ---------------------- loss: tensor([127.1616], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 68
#  ---------------------- loss: tensor([127.1318], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 69
#  ---------------------- loss: tensor([127.1024], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 70
#  ---------------------- loss: tensor([127.0735], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 71
#  ---------------------- loss: tensor([127.0450], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 72
#  ---------------------- loss: tensor([127.0170], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 73
#  ---------------------- loss: tensor([126.9894], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 74
#  ---------------------- loss: tensor([126.9620], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 75
#  ---------------------- loss: tensor([126.9351], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 76
#  ---------------------- loss: tensor([126.9084], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 77
#  ---------------------- loss: tensor([126.8821], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 78
#  ---------------------- loss: tensor([126.8559], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 79
#  ---------------------- loss: tensor([126.8300], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 80
#  ---------------------- loss: tensor([126.8044], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 81
#  ---------------------- loss: tensor([126.7789], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 82
#  ---------------------- loss: tensor([126.7535], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 83
#  ---------------------- loss: tensor([126.7283], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 84
#  ---------------------- loss: tensor([126.7032], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 85
#  ---------------------- loss: tensor([126.6782], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 86
#  ---------------------- loss: tensor([126.6533], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 87
#  ---------------------- loss: tensor([126.6285], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 88
#  ---------------------- loss: tensor([126.6037], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 89
#  ---------------------- loss: tensor([126.5789], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 90
#  ---------------------- loss: tensor([126.5542], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 91
#  ---------------------- loss: tensor([126.5294], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 92
#  ---------------------- loss: tensor([126.5045], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 93
#  ---------------------- loss: tensor([126.4797], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 94
#  ---------------------- loss: tensor([126.4547], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 95
#  ---------------------- loss: tensor([126.4297], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 96
#  ---------------------- loss: tensor([126.4046], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 97
#  ---------------------- loss: tensor([126.3794], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 98
#  ---------------------- loss: tensor([126.3541], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 99
#  ---------------------- loss: tensor([126.3287], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 100
#  ---------------------- loss: tensor([126.3031], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 101
#  ---------------------- loss: tensor([126.2773], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 102
#  ---------------------- loss: tensor([126.2514], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 103
#  ---------------------- loss: tensor([126.2252], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 104
#  ---------------------- loss: tensor([126.1990], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 105
#  ---------------------- loss: tensor([126.1724], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 106
#  ---------------------- loss: tensor([126.1457], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 107
#  ---------------------- loss: tensor([126.1187], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 108
#  ---------------------- loss: tensor([126.0915], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 109
#  ---------------------- loss: tensor([126.0641], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 110
#  ---------------------- loss: tensor([126.0363], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 111
#  ---------------------- loss: tensor([126.0083], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 112
#  ---------------------- loss: tensor([125.9801], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 113
#  ---------------------- loss: tensor([125.9515], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 114
#  ---------------------- loss: tensor([125.9227], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 115
#  ---------------------- loss: tensor([125.8935], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 116
#  ---------------------- loss: tensor([125.8640], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 117
#  ---------------------- loss: tensor([125.8341], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 118
#  ---------------------- loss: tensor([125.8039], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 119
#  ---------------------- loss: tensor([125.7734], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 120
#  ---------------------- loss: tensor([125.7425], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 121
#  ---------------------- loss: tensor([125.7113], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 122
#  ---------------------- loss: tensor([125.6796], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 123
#  ---------------------- loss: tensor([125.6475], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 124
#  ---------------------- loss: tensor([125.6151], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 125
#  ---------------------- loss: tensor([125.5823], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 126
#  ---------------------- loss: tensor([125.5490], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 127
#  ---------------------- loss: tensor([125.5152], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 128
#  ---------------------- loss: tensor([125.4810], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 129
#  ---------------------- loss: tensor([125.4463], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 130
#  ---------------------- loss: tensor([125.4113], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 131
#  ---------------------- loss: tensor([125.3757], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 132
#  ---------------------- loss: tensor([125.3396], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 133
#  ---------------------- loss: tensor([125.3029], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 134
#  ---------------------- loss: tensor([125.2658], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 135
#  ---------------------- loss: tensor([125.2281], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 136
#  ---------------------- loss: tensor([125.1899], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 137
#  ---------------------- loss: tensor([125.1510], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 138
#  ---------------------- loss: tensor([125.1116], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 139
#  ---------------------- loss: tensor([125.0717], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 140
#  ---------------------- loss: tensor([125.0310], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 141
#  ---------------------- loss: tensor([124.9898], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 142
#  ---------------------- loss: tensor([124.9479], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 143
#  ---------------------- loss: tensor([124.9053], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 144
#  ---------------------- loss: tensor([124.8621], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 145
#  ---------------------- loss: tensor([124.8181], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 146
#  ---------------------- loss: tensor([124.7734], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 147
#  ---------------------- loss: tensor([124.7280], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 148
#  ---------------------- loss: tensor([124.6818], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 149
#  ---------------------- loss: tensor([124.6348], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 150
#  ---------------------- loss: tensor([124.5870], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 151
#  ---------------------- loss: tensor([124.5383], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 152
#  ---------------------- loss: tensor([124.4888], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 153
#  ---------------------- loss: tensor([124.4384], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 154
#  ---------------------- loss: tensor([124.3870], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 155
#  ---------------------- loss: tensor([124.3348], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 156
#  ---------------------- loss: tensor([124.2815], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 157
#  ---------------------- loss: tensor([124.2273], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 158
#  ---------------------- loss: tensor([124.1719], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 159
#  ---------------------- loss: tensor([124.1155], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 160
#  ---------------------- loss: tensor([124.0580], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 161
#  ---------------------- loss: tensor([123.9993], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 162
#  ---------------------- loss: tensor([123.9395], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 163
#  ---------------------- loss: tensor([123.8784], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 164
#  ---------------------- loss: tensor([123.8161], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 165
#  ---------------------- loss: tensor([123.7524], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 166
#  ---------------------- loss: tensor([123.6874], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 167
#  ---------------------- loss: tensor([123.6210], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 168
#  ---------------------- loss: tensor([123.5531], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 169
#  ---------------------- loss: tensor([123.4837], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 170
#  ---------------------- loss: tensor([123.4127], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 171
#  ---------------------- loss: tensor([123.3401], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 172
#  ---------------------- loss: tensor([123.2658], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 173
#  ---------------------- loss: tensor([123.1897], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 174
#  ---------------------- loss: tensor([123.1118], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 175
#  ---------------------- loss: tensor([123.0320], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 176
#  ---------------------- loss: tensor([122.9502], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 177
#  ---------------------- loss: tensor([122.8663], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 178
#  ---------------------- loss: tensor([122.7803], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 179
#  ---------------------- loss: tensor([122.6920], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 180
#  ---------------------- loss: tensor([122.6015], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 181
#  ---------------------- loss: tensor([122.5084], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 182
#  ---------------------- loss: tensor([122.4128], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 183
#  ---------------------- loss: tensor([122.3145], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 184
#  ---------------------- loss: tensor([122.2135], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 185
#  ---------------------- loss: tensor([122.1095], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 186
#  ---------------------- loss: tensor([122.0023], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 187
#  ---------------------- loss: tensor([121.8921], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 188
#  ---------------------- loss: tensor([121.7784], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 189
#  ---------------------- loss: tensor([121.6612], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 190
#  ---------------------- loss: tensor([121.5402], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 191
#  ---------------------- loss: tensor([121.4153], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 192
#  ---------------------- loss: tensor([121.2862], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 193
#  ---------------------- loss: tensor([121.1527], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 194
#  ---------------------- loss: tensor([121.0146], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 195
#  ---------------------- loss: tensor([120.8715], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 196
#  ---------------------- loss: tensor([120.7232], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 197
#  ---------------------- loss: tensor([120.5694], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 198
#  ---------------------- loss: tensor([120.4097], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 199
#  ---------------------- loss: tensor([120.2437], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 200
#  ---------------------- loss: tensor([120.0710], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 201
#  ---------------------- loss: tensor([119.8912], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 202
#  ---------------------- loss: tensor([119.7037], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 203
#  ---------------------- loss: tensor([119.5080], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 204
#  ---------------------- loss: tensor([119.3034], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 205
#  ---------------------- loss: tensor([119.0893], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 206
#  ---------------------- loss: tensor([118.8649], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 207
#  ---------------------- loss: tensor([118.6294], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 208
#  ---------------------- loss: tensor([118.3817], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 209
#  ---------------------- loss: tensor([118.1208], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 210
#  ---------------------- loss: tensor([117.8455], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 211
#  ---------------------- loss: tensor([117.5544], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 212
#  ---------------------- loss: tensor([117.2458], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 213
#  ---------------------- loss: tensor([116.9179], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 214
#  ---------------------- loss: tensor([116.5685], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 215
#  ---------------------- loss: tensor([116.1952], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 216
#  ---------------------- loss: tensor([115.7951], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 217
#  ---------------------- loss: tensor([115.3646], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 218
#  ---------------------- loss: tensor([114.8996], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 219
#  ---------------------- loss: tensor([114.3951], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 220
#  ---------------------- loss: tensor([113.8450], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 221
#  ---------------------- loss: tensor([113.2420], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 222
#  ---------------------- loss: tensor([112.5763], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 223
#  ---------------------- loss: tensor([111.8361], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 224
#  ---------------------- loss: tensor([111.0061], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 225
#  ---------------------- loss: tensor([110.0657], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 226
#  ---------------------- loss: tensor([108.9873], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 227
#  ---------------------- loss: tensor([107.7325], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 228
#  ---------------------- loss: tensor([106.2461], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 229
#  ---------------------- loss: tensor([104.4450], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 230
#  ---------------------- loss: tensor([102.1978], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 231
#  ---------------------- loss: tensor([99.2819], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 232
#  ---------------------- loss: tensor([95.2848], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 233
#  ---------------------- loss: tensor([89.3365], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 234
#  ---------------------- loss: tensor([79.2190], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 235
#  ---------------------- loss: tensor([57.5677], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 236
#  ---------------------- loss: tensor([872.3283], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 237
#  ---------------------- loss: tensor([82.3639], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 238
#  ---------------------- loss: tensor([102.1929], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 239
#  ---------------------- loss: tensor([109.7545], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 240
#  ---------------------- loss: tensor([113.7137], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 241
#  ---------------------- loss: tensor([116.1392], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 242
#  ---------------------- loss: tensor([117.7711], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 243
#  ---------------------- loss: tensor([118.9391], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 244
#  ---------------------- loss: tensor([119.8126], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 245
#  ---------------------- loss: tensor([120.4874], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 246
#  ---------------------- loss: tensor([121.0218], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 247
#  ---------------------- loss: tensor([121.4533], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 248
#  ---------------------- loss: tensor([121.8073], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 249
#  ---------------------- loss: tensor([122.1013], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 250
#  ---------------------- loss: tensor([122.3481], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 251
#  ---------------------- loss: tensor([122.5570], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 252
#  ---------------------- loss: tensor([122.7352], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 253
#  ---------------------- loss: tensor([122.8881], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 254
#  ---------------------- loss: tensor([123.0199], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 255
#  ---------------------- loss: tensor([123.1340], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 256
#  ---------------------- loss: tensor([123.2331], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 257
#  ---------------------- loss: tensor([123.3195], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 258
#  ---------------------- loss: tensor([123.3951], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 259
#  ---------------------- loss: tensor([123.4611], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 260
#  ---------------------- loss: tensor([123.5191], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 261
#  ---------------------- loss: tensor([123.5699], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 262
#  ---------------------- loss: tensor([123.6145], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 263
#  ---------------------- loss: tensor([123.6537], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 264
#  ---------------------- loss: tensor([123.6881], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 265
#  ---------------------- loss: tensor([123.7183], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 266
#  ---------------------- loss: tensor([123.7448], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 267
#  ---------------------- loss: tensor([123.7681], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 268
#  ---------------------- loss: tensor([123.7883], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 269
#  ---------------------- loss: tensor([123.8060], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 270
#  ---------------------- loss: tensor([123.8214], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 271
#  ---------------------- loss: tensor([123.8347], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 272
#  ---------------------- loss: tensor([123.8462], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 273
#  ---------------------- loss: tensor([123.8561], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 274
#  ---------------------- loss: tensor([123.8645], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 275
#  ---------------------- loss: tensor([123.8716], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 276
#  ---------------------- loss: tensor([123.8775], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 277
#  ---------------------- loss: tensor([123.8823], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 278
#  ---------------------- loss: tensor([123.8862], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 279
#  ---------------------- loss: tensor([123.8893], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 280
#  ---------------------- loss: tensor([123.8916], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 281
#  ---------------------- loss: tensor([123.8932], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 282
#  ---------------------- loss: tensor([123.8942], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 283
#  ---------------------- loss: tensor([123.8946], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 284
#  ---------------------- loss: tensor([123.8946], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 285
#  ---------------------- loss: tensor([123.8940], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 286
#  ---------------------- loss: tensor([123.8931], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 287
#  ---------------------- loss: tensor([123.8918], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 288
#  ---------------------- loss: tensor([123.8902], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 289
#  ---------------------- loss: tensor([123.8883], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 290
#  ---------------------- loss: tensor([123.8861], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 291
#  ---------------------- loss: tensor([123.8837], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 292
#  ---------------------- loss: tensor([123.8811], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 293
#  ---------------------- loss: tensor([123.8782], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 294
#  ---------------------- loss: tensor([123.8752], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 295
#  ---------------------- loss: tensor([123.8720], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 296
#  ---------------------- loss: tensor([123.8687], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 297
#  ---------------------- loss: tensor([123.8652], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 298
#  ---------------------- loss: tensor([123.8616], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 299
#  ---------------------- loss: tensor([123.8579], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 300
#  ---------------------- loss: tensor([123.8541], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 301
#  ---------------------- loss: tensor([123.8502], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 302
#  ---------------------- loss: tensor([123.8463], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 303
#  ---------------------- loss: tensor([123.8422], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 304
#  ---------------------- loss: tensor([123.8381], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 305
#  ---------------------- loss: tensor([123.8340], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 306
#  ---------------------- loss: tensor([123.8297], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 307
#  ---------------------- loss: tensor([123.8254], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 308
#  ---------------------- loss: tensor([123.8211], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 309
#  ---------------------- loss: tensor([123.8167], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 310
#  ---------------------- loss: tensor([123.8123], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 311
#  ---------------------- loss: tensor([123.8078], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 312
#  ---------------------- loss: tensor([123.8034], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 313
#  ---------------------- loss: tensor([123.7988], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 314
#  ---------------------- loss: tensor([123.7943], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 315
#  ---------------------- loss: tensor([123.7897], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 316
#  ---------------------- loss: tensor([123.7851], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 317
#  ---------------------- loss: tensor([123.7805], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 318
#  ---------------------- loss: tensor([123.7759], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 319
#  ---------------------- loss: tensor([123.7712], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 320
#  ---------------------- loss: tensor([123.7666], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 321
#  ---------------------- loss: tensor([123.7619], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 322
#  ---------------------- loss: tensor([123.7571], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 323
#  ---------------------- loss: tensor([123.7524], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 324
#  ---------------------- loss: tensor([123.7477], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 325
#  ---------------------- loss: tensor([123.7429], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 326
#  ---------------------- loss: tensor([123.7381], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 327
#  ---------------------- loss: tensor([123.7333], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 328
#  ---------------------- loss: tensor([123.7286], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 329
#  ---------------------- loss: tensor([123.7238], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 330
#  ---------------------- loss: tensor([123.7189], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 331
#  ---------------------- loss: tensor([123.7141], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 332
#  ---------------------- loss: tensor([123.7093], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 333
#  ---------------------- loss: tensor([123.7044], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 334
#  ---------------------- loss: tensor([123.6996], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 335
#  ---------------------- loss: tensor([123.6947], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 336
#  ---------------------- loss: tensor([123.6898], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 337
#  ---------------------- loss: tensor([123.6850], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 338
#  ---------------------- loss: tensor([123.6801], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 339
#  ---------------------- loss: tensor([123.6752], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 340
#  ---------------------- loss: tensor([123.6703], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 341
#  ---------------------- loss: tensor([123.6654], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 342
#  ---------------------- loss: tensor([123.6604], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 343
#  ---------------------- loss: tensor([123.6555], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 344
#  ---------------------- loss: tensor([123.6506], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 345
#  ---------------------- loss: tensor([123.6456], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 346
#  ---------------------- loss: tensor([123.6407], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 347
#  ---------------------- loss: tensor([123.6357], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 348
#  ---------------------- loss: tensor([123.6307], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 349
#  ---------------------- loss: tensor([123.6257], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 350
#  ---------------------- loss: tensor([123.6208], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 351
#  ---------------------- loss: tensor([123.6158], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 352
#  ---------------------- loss: tensor([123.6108], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 353
#  ---------------------- loss: tensor([123.6057], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 354
#  ---------------------- loss: tensor([123.6008], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 355
#  ---------------------- loss: tensor([123.5957], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 356
#  ---------------------- loss: tensor([123.5907], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 357
#  ---------------------- loss: tensor([123.5857], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 358
#  ---------------------- loss: tensor([123.5806], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 359
#  ---------------------- loss: tensor([123.5756], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 360
#  ---------------------- loss: tensor([123.5705], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 361
#  ---------------------- loss: tensor([123.5655], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 362
#  ---------------------- loss: tensor([123.5604], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 363
#  ---------------------- loss: tensor([123.5553], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 364
#  ---------------------- loss: tensor([123.5502], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 365
#  ---------------------- loss: tensor([123.5452], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 366
#  ---------------------- loss: tensor([123.5401], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 367
#  ---------------------- loss: tensor([123.5350], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 368
#  ---------------------- loss: tensor([123.5298], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 369
#  ---------------------- loss: tensor([123.5247], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 370
#  ---------------------- loss: tensor([123.5196], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 371
#  ---------------------- loss: tensor([123.5145], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 372
#  ---------------------- loss: tensor([123.5093], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 373
#  ---------------------- loss: tensor([123.5042], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 374
#  ---------------------- loss: tensor([123.4991], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 375
#  ---------------------- loss: tensor([123.4939], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 376
#  ---------------------- loss: tensor([123.4888], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 377
#  ---------------------- loss: tensor([123.4836], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 378
#  ---------------------- loss: tensor([123.4784], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 379
#  ---------------------- loss: tensor([123.4732], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 380
#  ---------------------- loss: tensor([123.4680], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 381
#  ---------------------- loss: tensor([123.4629], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 382
#  ---------------------- loss: tensor([123.4577], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 383
#  ---------------------- loss: tensor([123.4525], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 384
#  ---------------------- loss: tensor([123.4473], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 385
#  ---------------------- loss: tensor([123.4421], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 386
#  ---------------------- loss: tensor([123.4368], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 387
#  ---------------------- loss: tensor([123.4316], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 388
#  ---------------------- loss: tensor([123.4264], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 389
#  ---------------------- loss: tensor([123.4211], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 390
#  ---------------------- loss: tensor([123.4159], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 391
#  ---------------------- loss: tensor([123.4106], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 392
#  ---------------------- loss: tensor([123.4054], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 393
#  ---------------------- loss: tensor([123.4001], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 394
#  ---------------------- loss: tensor([123.3948], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 395
#  ---------------------- loss: tensor([123.3896], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 396
#  ---------------------- loss: tensor([123.3843], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 397
#  ---------------------- loss: tensor([123.3790], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 398
#  ---------------------- loss: tensor([123.3737], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 399
#  ---------------------- loss: tensor([123.3684], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 400
#  ---------------------- loss: tensor([123.3631], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 401
#  ---------------------- loss: tensor([123.3578], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 402
#  ---------------------- loss: tensor([123.3524], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 403
#  ---------------------- loss: tensor([123.3471], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 404
#  ---------------------- loss: tensor([123.3418], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 405
#  ---------------------- loss: tensor([123.3364], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 406
#  ---------------------- loss: tensor([123.3311], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 407
#  ---------------------- loss: tensor([123.3258], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 408
#  ---------------------- loss: tensor([123.3204], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 409
#  ---------------------- loss: tensor([123.3150], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 410
#  ---------------------- loss: tensor([123.3097], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 411
#  ---------------------- loss: tensor([123.3043], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 412
#  ---------------------- loss: tensor([123.2989], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 413
#  ---------------------- loss: tensor([123.2935], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 414
#  ---------------------- loss: tensor([123.2881], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 415
#  ---------------------- loss: tensor([123.2827], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 416
#  ---------------------- loss: tensor([123.2773], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 417
#  ---------------------- loss: tensor([123.2719], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 418
#  ---------------------- loss: tensor([123.2665], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 419
#  ---------------------- loss: tensor([123.2611], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 420
#  ---------------------- loss: tensor([123.2557], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 421
#  ---------------------- loss: tensor([123.2502], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 422
#  ---------------------- loss: tensor([123.2448], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 423
#  ---------------------- loss: tensor([123.2393], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 424
#  ---------------------- loss: tensor([123.2339], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 425
#  ---------------------- loss: tensor([123.2284], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 426
#  ---------------------- loss: tensor([123.2230], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 427
#  ---------------------- loss: tensor([123.2175], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 428
#  ---------------------- loss: tensor([123.2120], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 429
#  ---------------------- loss: tensor([123.2065], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 430
#  ---------------------- loss: tensor([123.2010], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 431
#  ---------------------- loss: tensor([123.1955], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 432
#  ---------------------- loss: tensor([123.1901], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 433
#  ---------------------- loss: tensor([123.1846], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 434
#  ---------------------- loss: tensor([123.1790], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 435
#  ---------------------- loss: tensor([123.1735], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 436
#  ---------------------- loss: tensor([123.1680], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 437
#  ---------------------- loss: tensor([123.1625], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 438
#  ---------------------- loss: tensor([123.1569], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 439
#  ---------------------- loss: tensor([123.1514], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 440
#  ---------------------- loss: tensor([123.1458], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 441
#  ---------------------- loss: tensor([123.1403], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 442
#  ---------------------- loss: tensor([123.1347], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 443
#  ---------------------- loss: tensor([123.1292], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 444
#  ---------------------- loss: tensor([123.1236], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 445
#  ---------------------- loss: tensor([123.1181], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 446
#  ---------------------- loss: tensor([123.1125], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 447
#  ---------------------- loss: tensor([123.1069], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 448
#  ---------------------- loss: tensor([123.1013], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 449
#  ---------------------- loss: tensor([123.0957], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 450
#  ---------------------- loss: tensor([123.0901], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 451
#  ---------------------- loss: tensor([123.0845], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 452
#  ---------------------- loss: tensor([123.0789], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 453
#  ---------------------- loss: tensor([123.0733], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 454
#  ---------------------- loss: tensor([123.0676], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 455
#  ---------------------- loss: tensor([123.0620], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 456
#  ---------------------- loss: tensor([123.0564], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 457
#  ---------------------- loss: tensor([123.0507], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 458
#  ---------------------- loss: tensor([123.0451], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 459
#  ---------------------- loss: tensor([123.0394], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 460
#  ---------------------- loss: tensor([123.0338], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 461
#  ---------------------- loss: tensor([123.0281], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 462
#  ---------------------- loss: tensor([123.0225], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 463
#  ---------------------- loss: tensor([123.0168], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 464
#  ---------------------- loss: tensor([123.0111], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 465
#  ---------------------- loss: tensor([123.0054], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 466
#  ---------------------- loss: tensor([122.9997], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 467
#  ---------------------- loss: tensor([122.9940], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 468
#  ---------------------- loss: tensor([122.9883], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 469
#  ---------------------- loss: tensor([122.9826], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 470
#  ---------------------- loss: tensor([122.9769], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 471
#  ---------------------- loss: tensor([122.9712], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 472
#  ---------------------- loss: tensor([122.9655], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 473
#  ---------------------- loss: tensor([122.9597], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 474
#  ---------------------- loss: tensor([122.9540], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 475
#  ---------------------- loss: tensor([122.9483], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 476
#  ---------------------- loss: tensor([122.9425], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 477
#  ---------------------- loss: tensor([122.9368], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 478
#  ---------------------- loss: tensor([122.9310], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 479
#  ---------------------- loss: tensor([122.9253], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 480
#  ---------------------- loss: tensor([122.9195], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 481
#  ---------------------- loss: tensor([122.9137], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 482
# ...
# Epoch 9841
#  ---------------------- loss: tensor([7.0001], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9842
#  ---------------------- loss: tensor([7.2096], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9843
#  ---------------------- loss: tensor([7.5611], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9844
#  ---------------------- loss: tensor([9.6354], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9845
#  ---------------------- loss: tensor([7.7782], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9846
#  ---------------------- loss: tensor([8.0625], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9847
#  ---------------------- loss: tensor([7.4989], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9848
#  ---------------------- loss: tensor([8.1474], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9849
#  ---------------------- loss: tensor([7.7592], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9850
#  ---------------------- loss: tensor([9.2375], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9851
#  ---------------------- loss: tensor([7.5349], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9852
#  ---------------------- loss: tensor([7.4298], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9853
#  ---------------------- loss: tensor([7.1856], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9854
#  ---------------------- loss: tensor([7.4276], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9855
#  ---------------------- loss: tensor([7.4781], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9856
#  ---------------------- loss: tensor([8.7142], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9857
#  ---------------------- loss: tensor([7.7049], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9858
#  ---------------------- loss: tensor([8.3185], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9859
#  ---------------------- loss: tensor([7.4135], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9860
#  ---------------------- loss: tensor([7.5193], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9861
#  ---------------------- loss: tensor([7.2633], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9862
#  ---------------------- loss: tensor([7.6007], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9863
#  ---------------------- loss: tensor([7.4470], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9864
#  ---------------------- loss: tensor([8.2512], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9865
#  ---------------------- loss: tensor([7.5223], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9866
#  ---------------------- loss: tensor([7.9078], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9867
#  ---------------------- loss: tensor([7.3290], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9868
#  ---------------------- loss: tensor([7.4847], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9869
#  ---------------------- loss: tensor([7.2364], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9870
#  ---------------------- loss: tensor([7.5096], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9871
#  ---------------------- loss: tensor([7.3291], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9872
#  ---------------------- loss: tensor([7.8345], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9873
#  ---------------------- loss: tensor([7.4177], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9874
#  ---------------------- loss: tensor([7.8513], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9875
#  ---------------------- loss: tensor([7.3270], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9876
#  ---------------------- loss: tensor([7.5142], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9877
#  ---------------------- loss: tensor([7.2160], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9878
#  ---------------------- loss: tensor([7.4161], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9879
#  ---------------------- loss: tensor([7.2340], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9880
#  ---------------------- loss: tensor([7.5771], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9881
#  ---------------------- loss: tensor([7.3286], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9882
#  ---------------------- loss: tensor([7.7771], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9883
#  ---------------------- loss: tensor([7.3378], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9884
#  ---------------------- loss: tensor([7.6322], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9885
#  ---------------------- loss: tensor([7.2499], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9886
#  ---------------------- loss: tensor([7.4567], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9887
#  ---------------------- loss: tensor([7.2103], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9888
#  ---------------------- loss: tensor([7.4816], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9889
#  ---------------------- loss: tensor([7.2616], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9890
#  ---------------------- loss: tensor([7.6551], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9891
#  ---------------------- loss: tensor([7.3172], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9892
#  ---------------------- loss: tensor([7.7052], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9893
#  ---------------------- loss: tensor([7.2853], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9894
#  ---------------------- loss: tensor([7.5556], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9895
#  ---------------------- loss: tensor([7.2278], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9896
#  ---------------------- loss: tensor([7.4928], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9897
#  ---------------------- loss: tensor([7.2356], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9898
#  ---------------------- loss: tensor([7.5902], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9899
#  ---------------------- loss: tensor([7.2875], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9900
#  ---------------------- loss: tensor([7.7020], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9901
#  ---------------------- loss: tensor([7.2942], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9902
#  ---------------------- loss: tensor([7.6346], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9903
#  ---------------------- loss: tensor([7.2491], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9904
#  ---------------------- loss: tensor([7.5420], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9905
#  ---------------------- loss: tensor([7.2325], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9906
#  ---------------------- loss: tensor([7.5761], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9907
#  ---------------------- loss: tensor([7.2651], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9908
#  ---------------------- loss: tensor([7.6764], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9909
#  ---------------------- loss: tensor([7.2847], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9910
#  ---------------------- loss: tensor([7.6672], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9911
#  ---------------------- loss: tensor([7.2568], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9912
#  ---------------------- loss: tensor([7.5829], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9913
#  ---------------------- loss: tensor([7.2322], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9914
#  ---------------------- loss: tensor([7.5783], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9915
#  ---------------------- loss: tensor([7.2478], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9916
#  ---------------------- loss: tensor([7.6505], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9917
#  ---------------------- loss: tensor([7.2676], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9918
#  ---------------------- loss: tensor([7.6672], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9919
#  ---------------------- loss: tensor([7.2519], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9920
#  ---------------------- loss: tensor([7.6030], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9921
#  ---------------------- loss: tensor([7.2275], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9922
#  ---------------------- loss: tensor([7.5800], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9923
#  ---------------------- loss: tensor([7.2322], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9924
#  ---------------------- loss: tensor([7.6272], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9925
#  ---------------------- loss: tensor([7.2479], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9926
#  ---------------------- loss: tensor([7.6513], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9927
#  ---------------------- loss: tensor([7.2396], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9928
#  ---------------------- loss: tensor([7.6069], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9929
#  ---------------------- loss: tensor([7.2189], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9930
#  ---------------------- loss: tensor([7.5787], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9931
#  ---------------------- loss: tensor([7.2174], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9932
#  ---------------------- loss: tensor([7.6071], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9933
#  ---------------------- loss: tensor([7.2285], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9934
#  ---------------------- loss: tensor([7.6311], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9935
#  ---------------------- loss: tensor([7.2247], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9936
#  ---------------------- loss: tensor([7.6034], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9937
#  ---------------------- loss: tensor([7.2085], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9938
#  ---------------------- loss: tensor([7.5764], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9939
#  ---------------------- loss: tensor([7.2036], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9940
#  ---------------------- loss: tensor([7.5914], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9941
#  ---------------------- loss: tensor([7.2106], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9942
#  ---------------------- loss: tensor([7.6121], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9943
#  ---------------------- loss: tensor([7.2091], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9944
#  ---------------------- loss: tensor([7.5960], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9945
#  ---------------------- loss: tensor([7.1967], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9946
#  ---------------------- loss: tensor([7.5723], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9947
#  ---------------------- loss: tensor([7.1904], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9948
#  ---------------------- loss: tensor([7.5787], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9949
#  ---------------------- loss: tensor([7.1943], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9950
#  ---------------------- loss: tensor([7.5957], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9951
#  ---------------------- loss: tensor([7.1939], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9952
#  ---------------------- loss: tensor([7.5868], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9953
#  ---------------------- loss: tensor([7.1843], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9954
#  ---------------------- loss: tensor([7.5671], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9955
#  ---------------------- loss: tensor([7.1776], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9956
#  ---------------------- loss: tensor([7.5684], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9957
#  ---------------------- loss: tensor([7.1791], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9958
#  ---------------------- loss: tensor([7.5810], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9959
#  ---------------------- loss: tensor([7.1787], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9960
#  ---------------------- loss: tensor([7.5760], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9961
#  ---------------------- loss: tensor([7.1712], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9962
#  ---------------------- loss: tensor([7.5607], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9963
#  ---------------------- loss: tensor([7.1648], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9964
#  ---------------------- loss: tensor([7.5587], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9965
#  ---------------------- loss: tensor([7.1644], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9966
#  ---------------------- loss: tensor([7.5669], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9967
#  ---------------------- loss: tensor([7.1636], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9968
#  ---------------------- loss: tensor([7.5646], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9969
#  ---------------------- loss: tensor([7.1578], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9970
#  ---------------------- loss: tensor([7.5526], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9971
#  ---------------------- loss: tensor([7.1517], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9972
#  ---------------------- loss: tensor([7.5486], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9973
#  ---------------------- loss: tensor([7.1499], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9974
#  ---------------------- loss: tensor([7.5535], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9975
#  ---------------------- loss: tensor([7.1488], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9976
#  ---------------------- loss: tensor([7.5526], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9977
#  ---------------------- loss: tensor([7.1441], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9978
#  ---------------------- loss: tensor([7.5437], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9979
#  ---------------------- loss: tensor([7.1386], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9980
#  ---------------------- loss: tensor([7.5389], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9981
#  ---------------------- loss: tensor([7.1360], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9982
#  ---------------------- loss: tensor([7.5414], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9983
#  ---------------------- loss: tensor([7.1344], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9984
#  ---------------------- loss: tensor([7.5405], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9985
#  ---------------------- loss: tensor([7.1301], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9986
#  ---------------------- loss: tensor([7.5330], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9987
#  ---------------------- loss: tensor([7.1249], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9988
#  ---------------------- loss: tensor([7.5281], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9989
#  ---------------------- loss: tensor([7.1221], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9990
#  ---------------------- loss: tensor([7.5294], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9991
#  ---------------------- loss: tensor([7.1202], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9992
#  ---------------------- loss: tensor([7.5287], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9993
#  ---------------------- loss: tensor([7.1162], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9994
#  ---------------------- loss: tensor([7.5219], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9995
#  ---------------------- loss: tensor([7.1112], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9996
#  ---------------------- loss: tensor([7.5166], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9997
#  ---------------------- loss: tensor([7.1080], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9998
#  ---------------------- loss: tensor([7.5172], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 9999
#  ---------------------- loss: tensor([7.1059], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 10000
#  ---------------------- loss: tensor([7.5161], device='cuda:0', grad_fn=<DivBackward0>)
# Epoch 10001
#  ---------------------- loss: tensor([7.1021], device='cuda:0', grad_fn=<DivBackward0>)
# Done!
# 235.68787145614624

# %%
plt.subplots(1,2,figsize=(12,4))
plt.subplot(121)
plt.plot(epochs, Es, "r.", label="Energies")
plt.title("Eigenvalues of Energy")
#plt.yscale("log")
plt.xlabel("Epochs")
plt.ylabel("Energy")
plt.grid()
plt.legend(loc="best")
plt.subplot(122)
plt.plot(epochs, lss, "b.", label="Losses")
plt.title("Loss per 100 epochs")
plt.yscale("log")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.legend(loc="best")
plt.show()

# %%
rr = np.linspace(lower_r, upper_r, steps)[:,None]
fig, axs = plt.subplots(3,3,figsize=(15,10))

fil = 0
col = 0
for i in range(0,9):
    yy = Phis_t[50*i]
    yy = yy.reshape((200,1))
    axs[fil,col].plot(rr[100:], np.divide(yy[100:], rr[100:]), ".", label=f"Epochs {epochs[50*i]}")
    axs[fil,col].set_xlabel("$r$")
    axs[fil,col].set_ylabel("$R(r)$")
    axs[fil,col].legend(loc="best")
    axs[fil,col].ticklabel_format(style='sci', axis='y', scilimits=(0,0))
    axs[fil,col].grid()
    if col == 2:
       col = 0
       fil = fil+1
    else:
       col = col+1
plt.rc("font", size=8)
plt.tight_layout()
plt.show()

# %%
Es
# Out:
# array([1.6736456 , 1.3373748 , 1.3183837 , ..., 0.6515659 , 0.67456824,
#        0.651516  ], dtype=float32)

# %%
np.mean(Es)
# Out:
# 0.99978596

# %%
norm = torch.trapezoid(Phi_t(R_train.to(device)).cpu()[100:]**2,R_train.cpu()[100:],dim=0).detach().numpy()
#norm = norm.detach()
norm
# Out:
# array([4.6465062e-05], dtype=float32)

# %%
torch.trapezoid(Phi_t(R_train.to(device)).cpu()[100:]**2,R_train[100:].cpu(),dim=0).detach().numpy()/norm
# Out:
# array([1.], dtype=float32)

# %%
Phi_0 = Phi_t(R_train.to(device))
#Phi_0 = Phi_0/torch.sqrt(norm)
Phi_0 = Phi_0.detach()
new = torch.trapezoid(Phi_0.cpu()[100:]**2,R_train.cpu()[100:],dim=0).detach().numpy()
new
# Out:
# array([4.6465062e-05], dtype=float32)

# %%
plt.plot(R_train.cpu().detach().numpy(), Phi_0.cpu().detach().numpy(), ".")

# %%
R_0 = torch.divide(Phi_0.to(device), R_train.to(device)).cpu()
plt.plot(R_train.cpu().detach().numpy(), R_0.cpu().detach().numpy(), ".")

# %%
norm1 = torch.trapezoid(R_0.to(device)[100:]**2,R_train.to(device)[100:],dim=0).cpu()
norm1 = norm1.detach().numpy()
norm1
# Out:
# array([0.00023914], dtype=float32)

# %%
R_0 = R_0/torch.sqrt(torch.tensor(norm1))
plt.plot(R_train.detach().numpy()[100:], R_0.detach().numpy()[100:], ".")

# %%
torch.trapezoid(R_0.cpu()[100:]**2,R_train.cpu()[100:],dim=0)
# Out:
# tensor([1.0000])

# %%
#file_Phi = open("file1.txt","w")
#for row in Phi_0:
    #np.savetxt(file_Phi, row)
#file_Phi.close()
